# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from format_results import *
import statistics

# %%
def draw_boxplot(data, title):
    plt.clf()
    df = pd.DataFrame(data=data)
    #print(df.T)
    plt.rcParams['figure.figsize'] = [15, 10]

    fig = plt.figure();
    fig.suptitle(title, fontsize=14, fontweight='bold')

    bp = df.T.boxplot(fontsize=14)

# %%
def draw_line_graph_acc_f1(acc_1, f1_1, t_1, acc_2, f1_2, t_2, acc_3, f1_3, t_3, ylabel, xlabel):
    plt.clf()
    #df = pd.DataFrame(data=data)
    #print(df.T)
    plt.rcParams['figure.figsize'] = [25, 5]
    
    ax = gca()
    ax.xaxis.set_tick_params(labelsize=14)
    ax.yaxis.set_tick_params(labelsize=14)
    
    
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["font.size"] = "16"

    if acc_1 != None:
        plt.subplot(131)

        plt.plot(acc_1)
        plt.plot(f1_1)
        plt.title(t_1, fontsize=16, fontweight='bold')
        plt.legend(['accuracy', 'f1'], loc='upper left')

        plt.ylabel(ylabel, fontweight='bold')
        plt.xlabel(xlabel, fontweight='bold')
        plt.hlines(statistics.mean(acc_1), 0, len(acc_1) -1, linestyles='dashed')
        plt.hlines(statistics.mean(f1_1), 0, len(acc_1) -1, linestyles='dashed')

    
    if acc_2 != None:
        plt.subplot(132)


        plt.plot(acc_2)
        plt.plot(f1_2)
        plt.title(t_2, fontsize=16, fontweight='bold')

        plt.legend(['accuracy', 'f1'], loc='upper left')

        plt.ylabel(ylabel, fontweight='bold')
        plt.xlabel(xlabel, fontweight='bold')
        plt.hlines(statistics.mean(acc_2), 0, len(acc_2) -1, linestyles='dashed')
        plt.hlines(statistics.mean(f1_2), 0, len(acc_2) -1, linestyles='dashed')
    
    if acc_3 != None:
        plt.subplot(133)

        plt.plot(acc_3)
        plt.plot(f1_3)
        plt.title(t_3, fontweight='bold')
        plt.legend(['accuracy', 'f1'], loc='upper left')

        plt.ylabel(ylabel, fontweight='bold')
        plt.xlabel(xlabel, fontweight='bold')
        plt.hlines(statistics.mean(acc_3), 0, len(acc_3) -1, linestyles='dashed')
        plt.hlines(statistics.mean(f1_3), 0, len(acc_3) -1, linestyles='dashed')

    
    plt.show()

# %%
test_acc_1, max_acc_1 = get_raw_100('test_acc')
test_f1s_1, max_f1_1 = get_raw_100('test_f1')

test_acc_2, max_acc_2 = get_raw_200('test_acc')
test_f1s_2, max_f1_2 = get_raw_200('test_f1')

test_acc_4, max_acc_4 = get_raw_400('test_acc')
test_f1s_4, max_f1_4 = get_raw_400('test_f1')

draw_line_graph_acc_f1(max_acc_1, max_f1_1, 'Sentence Length: 100',
                       max_acc_2, max_f1_2, 'Sentence Length: 200',
                       max_acc_4, max_f1_4, 'Sentence Length: 400', 
                       'Scores', 'Iterations')

# %%
test_acc_1, max_acc_1 = get_raw_100('test_acc')
test_f1s_1, max_f1_1 = get_raw_100('test_f1')

test_acc_2, max_acc_2 = get_raw_200('test_acc')
test_f1s_2, max_f1_2 = get_raw_200('test_f1')

test_acc_4, max_acc_4 = get_raw_400('test_acc')
test_f1s_4, max_f1_4 = get_raw_400('test_f1')

draw_line_graph_acc_f1(None, None, 'Sentence Length: 100',
                       None, None, 'Sentence Length: 200',
                       max_acc_4, max_f1_4, 'Sentence Length: 400', 
                       'Scores', 'Iterations')

# %%
test_acc_r, max_acc_r = get_raw_200('test_acc')
test_f1s_r, max_f1_r = get_raw_200('test_f1')

test_acc_x, max_acc_x = get_raw_200_xavier('test_acc')
test_f1s_x, max_f1_x = get_raw_200_xavier('test_f1')

test_acc_c, max_acc_c = get_raw_200_clean('test_acc')
test_f1s_c, max_f1_c = get_raw_200_clean('test_f1')

draw_line_graph_acc_f1(max_acc_r, max_f1_r, 'Random Uniform Initializer',
                       max_acc_x, max_f1_x, 'Xavier Initializer ',
                       None, None, 'Clean Data - Xavier Optimizer', 
                       'Score', 'Iterations')
#draw_boxplot(test_accuracies, 'Test Accuracy (Raw data - Review Length 200)')

# %%
test_acc_1, max_acc_1 = get_raw_200_40Iter('test_acc')
test_f1s_1, max_f1_1 = get_raw_200_40Iter('test_f1')

test_acc_2, max_acc_2 = get_pos_200_40Iter('test_acc')
test_f1s_2, max_f1_2 = get_pos_200_40Iter('test_f1')

draw_line_graph_acc_f1(max_acc_1, max_f1_1, 'Before',
                       max_acc_2, max_f1_2, 'After',
                       None, None, '', 
                       'Scores', 'Iterations')

# %%
def draw_line_graph_acc_loss_f1(acc, loss, prec, recal, f1, ylabel, xlabel):
    plt.clf()
    #df = pd.DataFrame(data=data)
    #print(df.T)
    plt.rcParams['figure.figsize'] = [20, 5]

    plt.subplot(131)
    
    plt.plot(acc)
    plt.plot(loss)
    plt.title('Loss-Accuracy (acc:' + str(round(max(acc), 4)) +
              ', loss:' + str(round(min(loss), 4)) + ')')
    plt.legend(['accuracy', 'loss'], loc='upper left')
    
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    
    plt.subplot(132)
    
    plt.plot(f1)
    plt.title('F1 (' + str(round(max(f1), 4)) + ')')
    plt.legend(['f1'], loc='upper left')
    
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    
    plt.subplot(133)
    
    plt.plot(prec)
    plt.plot(recal)
    
    plt.title('Precision-Recall (prec:' + str(round(max(prec), 4)) + 
              ',rec:' + str(round(max(recal), 4)) + ')')
    
    plt.legend(['precision', 'recall'], loc='upper left')
    
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)    
    
    plt.show()

# %%
test_accuracies, test_max_acc = get_pos_200_40Iter_max('test_acc')
train_loss, train_loss_max = get_pos_200_40Iter_max('loss')
train_f1, train_f1_max = get_raw_200_xavier_max('test_f1')
train_prec, train_prec_max = get_raw_200_xavier_max('test_prec')
train_recall, train_recall_max = get_raw_200_xavier_max('test_recall')

train_loss[0] = [x / 10 for x in train_loss[0]]

draw_line_graph_acc_loss_f1(test_accuracies[0], train_loss[0], train_prec[0], train_recall[0],
                        train_f1[0], 'Scores', 'Iterations')

# %%
test_acc_1, max_acc_1 = get_raw_200_MaxIter('test_acc')
test_f1s_1, max_f1_1 = get_raw_200_MaxIter('test_f1')

test_acc_2, max_acc_2 = get_pos_200_MaxIter('test_acc')
test_f1s_2, max_f1_2 = get_pos_200_MaxIter('test_f1')

draw_line_graph_acc_f1(max_acc_1, max_f1_1, 'Raw | Max Iter',
                       max_acc_2, max_f1_2, 'Raw | Max Iter | Pos Embed Tweaks',
                       None, None, '', 
                       'Scores', 'Iterations')

# %%
test_accuracies, test_max_acc = get_pos_200_MaxIter_max('test_acc')
train_loss, train_loss_max = get_pos_200_MaxIter_max('loss')
train_f1, train_f1_max = get_pos_200_MaxIter_max('test_f1')
train_prec, train_prec_max = get_pos_200_MaxIter_max('test_prec')
train_recall, train_recall_max = get_pos_200_MaxIter_max('test_recall')

train_loss[0] = [x / 10 for x in train_loss[0]]

draw_line_graph_acc_loss_f1(test_accuracies[0], train_loss[0], train_prec[0], train_recall[0], 
                            train_f1[0], 'Scores', 'Iterations')

# %% [markdown]
# ### Unsuccessful Experiments

# %%
test_acc_m, max_acc_m = get_mix_200('test_acc')
test_f1s_m, max_f1_m = get_mix_200('test_f1')

test_acc_x, max_acc_x = get_lemma_200('test_acc')
test_f1s_x, max_f1_x = get_lemma_200('test_f1')

test_acc_p, max_acc_p = get_polarity_200('test_acc')
test_f1s_p, max_f1_p = get_polarity_200('test_f1')

draw_line_graph_acc_f1(max_acc_m, max_f1_m, 'Mix - Positive/Negative Reviews',
                       max_acc_x, max_f1_x, 'After Lemmatization',
                       max_acc_p, max_f1_p, 'More Weights to Polarized Words', 
                       'Scores', 'Iterations')

# %%
#run with the dev data
#remove lemma
